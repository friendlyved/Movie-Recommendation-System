# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %% [markdown]
# # 2020 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
len(tables)
# Out:
# 4

# %%
type(tables[0])
# Out:
# bs4.element.Tag

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df1
# Out:
#      Opening  Opening.1                                   Title  \
# 0    JANUARY          3                              The Grudge
# 1    JANUARY         10                              Underwater
# 2    JANUARY         10                             Like a Boss
# 3    JANUARY         10                           Three Christs
# 4    JANUARY         10                       Inherit the Viper
# 5    JANUARY         10                              The Sonata
# 6    JANUARY         10      The Murder of Nicole Brown Simpson
# 7    JANUARY         17                       Bad Boys for Life
# 8    JANUARY         17                                Dolittle
# 9    JANUARY         17                       A Fall from Grace
# 10   JANUARY         24                           The Gentlemen
# 11   JANUARY         24                             The Turning
# 12   JANUARY         24                   The Last Full Measure
# 13   JANUARY         24                              John Henry
# 14   JANUARY         31                      The Rhythm Section
# 15   JANUARY         31                         Gretel & Hansel
# 16   JANUARY         31                           The Assistant
# 17  FEBRUARY          7                           Birds of Prey
# 18  FEBRUARY          7                               The Lodge
# 19  FEBRUARY          7       Timmy Failure: Mistakes Were Made
# 20  FEBRUARY          7                              Horse Girl
# 21  FEBRUARY         12  To All the Boys: P.S. I Still Love You
# 22  FEBRUARY         14                      Sonic the Hedgehog
# 23  FEBRUARY         14                          Fantasy Island
# 24  FEBRUARY         14                          The Photograph
# 25  FEBRUARY         14                                Downhill
# 26  FEBRUARY         14                        Spy Intervention
# 27  FEBRUARY         14               The Kindness of Strangers
# 28  FEBRUARY         21                    The Call of the Wild
# 29  FEBRUARY         21                The Last Thing He Wanted
# 30  FEBRUARY         21                      Brahms: The Boy II
# 31  FEBRUARY         21                                    Emma
# 32  FEBRUARY         21                         The Night Clerk
# 33  FEBRUARY         21           Impractical Jokers: The Movie
# 34  FEBRUARY         28                       The Invisible Man
# 35  FEBRUARY         28                   All the Bright Places
# 36  FEBRUARY         28                                   Wendy
# 37  FEBRUARY         28                             Guns Akimbo
# 38     MARCH          6                                  Onward
# 39     MARCH          6                            The Way Back
# 40     MARCH          6                    Spenser Confidential
# 41     MARCH          6                              The Banker
# 42     MARCH          6                 The Burnt Orange Heresy
# 43     MARCH          6                                 Swallow
# 44     MARCH          6                               First Cow
# 45     MARCH         13                               Bloodshot
# 46     MARCH         13                                The Hunt
# 47     MARCH         13                         I Still Believe
# 48     MARCH         13                              Lost Girls
# 49     MARCH         13                                Stargirl
# 50     MARCH         13                     The Roads Not Taken
# 51     MARCH         13           Never Rarely Sometimes Always
# 52     MARCH         13                    Big Time Adolescence
# 53     MARCH         13                      Lost Transmissions
# 54     MARCH         27                              Resistance
# 55     MARCH         27                                Uncorked
# 56     MARCH         27                                Vivarium
#
#                                    Production company  \
# 0   Screen Gems / Stage 6 Films / Ghost House Pict...
# 1   20th Century Fox / TSG Entertainment / Chernin...
# 2                                  Paramount Pictures
# 3                                           IFC Films
# 4      Barry Films / Tycor International Film Company
# 5                                  Screen Media Films
# 6                                 Quiver Distribution
# 7   Columbia Pictures / Don Simpson/Jerry Bruckhei...
# 8         Universal Pictures / Perfect World Pictures
# 9                                             Netflix
# 10                                STX Films / Miramax
# 11  Universal Pictures / DreamWorks Pictures / Amb...
# 12                               Roadside Attractions
# 13                                        Saban Films
# 14               Paramount Pictures / Eon Productions
# 15                     Orion Pictures / Bron Creative
# 16                                    Bleecker Street
# 17                   Warner Bros. Pictures / DC Films
# 18     Neon / FilmNation Entertainment / Hammer Films
# 19                     Walt Disney Pictures / Disney+
# 37  Jason Lei Howden (director/screenplay); Daniel...
# 38  Dan Scanlon (director/screenplay); Jason Headl...
# 39  Gavin O'Connor (director); Brad Ingelsby (scre...
# 40  Peter Berg (director); Sean O'Keefe, Brian Hel...
# 41  George Nolfi (director/screenplay); Niceole Le...
# 42  Giuseppe Capotondi (director); Scott Smith (sc...
# 43  Carlo Mirabella-Davis (director/screenplay); H...
# 44  Kelly Reichardt (director/screenplay); Jonatha...
# 45  Dave S. F. Wilson (director); Jeff Wadlow, Eri...
# 46  Craig Zobel (director); Nick Cuse, Damon Linde...
# 47  Erwin Brothers (directors); Jon Erwin, Jon Gun...
# 48  Liz Garbus (director); Michael Werwie (screenp...
# 49  Julia Hart (director/screenplay); Kristin Hahn...
# 50  Sally Potter (director/screenplay); Javier Bar...
# 51  Eliza Hittman (director/screenplay); Sidney Fl...
# 52  Jason Orley (director); Jason Orley (screenpla...
# 53  Katharine O'Brien (director/screenplay); Simon...
# 54  Jonathan Jakubowicz (director/screenplay); Jes...
# 55  Prentice Penny (director/screenplay); Mamoudou...
# 56  Lorcan Finnegan (director); Imogen Poots, Jess...
#
#    .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.
# 0                                                 [2]
# 1                                                 [3]
# 2                                                 [4]
# 3                                                 NaN
# 4                                                 [5]
# 5                                                 [6]
# 6                                                 [7]
# 7                                                 [8]
# 8                                                 [9]
# 9                                                [10]
# 10                                               [11]
# 11                                               [12]
# 12                                               [13]
# 13                                               [14]
# 14                                               [15]
# 15                                               [16]
# 16                                               [17]
# 17                                               [18]
# 18                                               [19]
# 19                                               [20]
# 20                                               [21]
# 21                                               [22]
# 22                                               [23]
# 23                                               [24]
# 24                                               [25]
# 25                                               [26]
# 26                                               [27]
# 27                                               [28]
# 28                                                [3]
# 29                                               [29]
# 30                                               [30]
# 31                                               [31]
# 32                                               [32]
# 33                                               [33]
# 34                                               [34]
# 35                                               [35]
# 36                                               [36]
# 37                                               [37]
# 38                                               [38]
# 39                                               [39]
# 40                                               [40]
# 41                                               [41]
# 42                                               [42]
# 43                                               [43]
# 44                                               [44]
# 45                                               [45]
# 46                                               [46]
# 47                                               [47]
# 48                                               [48]
# 49                                               [49]
# 50                                               [50]
# 51                                               [51]
# 52                                               [52]
# 53                                               [53]
# 54                                               [54]
# 55                                               [55]
# 56                                               [56]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df_2020 = df[['Title','Cast and crew']]

# %%
df_2020
# Out:
#                      Title                                      Cast and crew
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 269       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 270      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 271  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 272  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 273      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
# [274 rows x 2 columns]

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '8a9637e6ab80fe86f4d9036359d11819'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie() 
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['genres']:
          genre_str = " " 
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return genre_str.join(genres)
      else:
          return np.NaN

# %%
df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre(str(x)))

# %% [markdown]
# # 2021 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2021"

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
len(tables)
# Out:
# 4

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df_2021 = df[['Title','Cast and crew']]

# %%
df_2021['genres'] = df_2021['Title'].map(lambda x: get_genre(str(x)))
# Out:
# <ipython-input-46-252c1cda1e49>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['genres'] = df_2021['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2020.isnull().sum()
# Out:
# Title            0
# Cast and crew    0
# genres           1
# dtype: int64

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))
df_2021['director_name'] = df_2021['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2020["actor_1_name"]=df_2020["Cast and crew"].map(lambda x:get_actor1(x))
df_2021["actor_1_name"]=df_2021["Cast and crew"].map(lambda x:get_actor1(x))
# Out:
# <ipython-input-59-0b73074a01fe>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021["actor_1_name"]=df_2021["Cast and crew"].map(lambda x:get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(str(x)))
df_2021['actor_2_name'] = df_2021['Cast and crew'].map(lambda x: get_actor2(str(x)))
# Out:
# <ipython-input-62-04a4ed18a115>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['actor_2_name'] = df_2021['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(str(x)))
df_2021['actor_3_name'] = df_2021['Cast and crew'].map(lambda x: get_actor3(str(x)))
# Out:
# <ipython-input-78-93b746d0656e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['actor_3_name'] = df_2021['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2020 = df_2020.rename(columns={'Title':'movie_title'})
df_2021 = df_2021.rename(columns={'Title':'movie_title'})

# %%
new_df20 = df_2020.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]
new_df21 = df_2021.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df21
# Out:
#          director_name        actor_1_name       actor_2_name  \
# 0       Roseanne Liang  Chloë Grace Moretz  Taylor John Smith
# 1        Ramin Bahrani       Adarsh Gourav      Rajkummar Rao
# 2           Doug Liman       Anne Hathaway   Chiwetel Ejiofor
# 3          Simon Stone      Carey Mulligan      Ralph Fiennes
# 4      Mikael Håfström      Anthony Mackie       Damson Idris
# ..                 ...                 ...                ...
# 351     Lana Wachowski        Keanu Reeves   Carrie-Anne Moss
# 352     Matthew Vaughn       Ralph Fiennes     Gemma Arterton
# 353          Joel Coen   Denzel Washington  Frances McDormand
# 354  Denzel Washington   Michael B. Jordan       Chanté Adams
# 355     Erwin brothers        Zachary Levi        Anna Paquin
#
#               actor_3_name                            genres  \
# 0             Beulah Koale                 Horror Action War
# 1    Priyanka Chopra Jonas                             Drama
# 2         Stephen Merchant                Comedy Crime Drama
# 3               Lily James                     Drama History
# 4            Emily Beecham   Thriller Action Science Fiction
# ..                     ...                               ...
# 351  Yahya Abdul-Mateen II  Science Fiction Action Adventure
# 352             Rhys Ifans     Action Adventure Thriller War
# 353          Bertie Carvel                         Drama War
# 354        Jalon Christian                     Drama Romance
# 355           Dennis Quaid                             Drama
#
#                   movie_title
# 0         Shadow in the Cloud
# 1             The White Tiger
# 2                 Locked Down
# 3                     The Dig
# 4            Outside the Wire
# ..                        ...
# 351  The Matrix Resurrections
# 352            The King's Man
# 353    The Tragedy of Macbeth
# 354      A Journal for Jordan
# 355         American Underdog
#
# [356 rows x 6 columns]

# %%
new_df20['comb'] = new_df20['actor_1_name'] + ' ' + new_df20['actor_2_name'] + ' '+ new_df20['actor_3_name'] + ' '+ new_df20['director_name'] +' ' + new_df20['genres']

# %%
new_df21['comb'] = new_df21['actor_1_name'] + ' ' + new_df21['actor_2_name'] + ' '+ new_df21['actor_3_name'] + ' '+ new_df21['director_name'] +' ' + new_df21['genres']

# %%
new_df20.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      4
# actor_3_name     27
# genres            1
# movie_title       0
# comb             28
# dtype: int64

# %%
new_df21.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      8
# actor_3_name     25
# genres            1
# movie_title       0
# comb             26
# dtype: int64

# %%
new_df20 = new_df20.dropna(how='any')
new_df21 = new_df21.dropna(how='any')

# %%
new_df20.shape,new_df21.shape
# Out:
# ((246, 7), (330, 7))

# %%
old_df = pd.read_csv('final_data.csv')

# %%
final_df.shape
# Out:
# (6454, 7)

# %%
new_df20.head()
# Out:
#     director_name        actor_1_name       actor_2_name     actor_3_name  \
# 0   Nicolas Pesce  Andrea Riseborough      Demián Bichir         John Cho
# 1  William Eubank     Kristen Stewart     Vincent Cassel  Jessica Henwick
# 2   Miguel Arteta     Tiffany Haddish         Rose Byrne      Salma Hayek
# 3       Jon Avnet        Richard Gere     Peter Dinklage   Walton Goggins
# 4  Anthony Jerjen       Josh Hartnett  Margarita Levieva   Chandler Riggs
#
#                                    genres        movie_title  \
# 0                 Horror Mystery Thriller         The Grudge
# 1  Action Horror Science Fiction Thriller         Underwater
# 2                                  Comedy        Like a Boss
# 3                                   Drama      Three Christs
# 4                    Crime Thriller Drama  Inherit the Viper
#
#                                                 comb
# 0  Andrea Riseborough Demián Bichir John Cho Nico...
# 1  Kristen Stewart Vincent Cassel Jessica Henwick...
# 2  Tiffany Haddish Rose Byrne Salma Hayek Miguel ...
# 3  Richard Gere Peter Dinklage Walton Goggins Jon...
# 4  Josh Hartnett Margarita Levieva Chandler Riggs...

# %%
final_df = old_df.append(new_df20,ignore_index=True)

# %%
final_df = final_df.append(new_df21,ignore_index=True)

# %%
final_df.drop_duplicates(subset ="movie_title", keep = 'last', inplace = True)

# %%
final_df.to_csv('main_data.csv',index=False)
